# %% [markdown]
# # Data Analysis of Acoustics Experiments
#
# (c) Benjamin Cichos 2019

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.interpolate
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.rcParams.update({'font.size': 14,
                     'axes.titlesize': 18,
                     'axes.labelsize': 18,
                     'axes.labelpad': 14,
                     'lines.linewidth': 1,
                     'lines.markersize': 10,
                     'xtick.labelsize' : 16,
                     'ytick.labelsize' : 16,
                     'xtick.top' : True,
                     'xtick.direction' : 'in',
                     'ytick.right' : True,
                     'ytick.direction' : 'in',})

# %%
pwd
# Out:
# '/Users/fci/Dropbox/Physics IA Data/6_units_with_aperture'

# %%
ls
# Out:
# 6_units_with_aperture       6_units_with_aperture_5hz
# 6_units_with_aperture_20hz  Untitled.ipynb

# %%
freq,amp=np.loadtxt('6_units_with_aperture',unpack=True)

# %%
fig=plt.figure(figsize=(10,5))
ax=fig.gca()
plt.plot(freq,amp/10000)
plt.xlabel('frequency [Hz]')
plt.ylabel('amplitude [a.u.]')
plt.ticklabel_format(axis='both',style='sci')
plt.show()
